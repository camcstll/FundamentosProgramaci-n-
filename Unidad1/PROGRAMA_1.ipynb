# %% [markdown]
# <a href="https://colab.research.google.com/github/camcstll/FundamentosProgramaci-n-/blob/main/Unidad1/PROGRAMA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INGENIERÍA EN SISTEMAS COMPUTACIONALES**
#
# ## **Fundamentos de Programación**
#
# ## **Unidad 1**
#
# ### Práctica 1: Introducción al lenguaje de Programación de Python
#
# Docente: **José Gabriel Rodríguez Rivas**
#
# Alumna: **Camila Pérez Castillo**

# %%
X = 5
X = "Hola Mundo"
x = True
print ("el valor de x es", "X")

# %%
base = int (input ("Dame la base del triángulo"))
altura = int (input ("Dame la altura del triángulo"))
area = (base * altura) / 2
print ("El área del triángulo es", area)
# Out:
# Dame la base del triángulo10
# Dame la altura del triángulo20
# El área del triángulo es 100.0

# %%
variable1 = 30
variable2 = 50
if variable1 > variable2:
  print ("La variable1 es mayor que la variable2")
else:
  print ("La variable2 es mayor que la variable1")
# Out:
# La variable2 es mayor que la variable1

# %%
variable1 = 70
variable2 = 70
if variable1 > variable2:
  print (variable1, "es mayor que", variable2)
else:
  print (variable2, "es mayor que", variable1)
# Out:
# 70 es mayor que 70

# %%
variable1 = 70
variable2 = 70
if variable1 > variable2:
  print (variable1, "es mayor que", variable2)
elif variable1 == variable2:
    print (variable1, "es igual que", variable2)
else:
  print (variable2, "es mayor que", variable1)
# Out:
# 70 es igual que 70

# %%
edad = int (input ("Dame tu edad"))
if edad <= 10:
  print ("Eres un niño")
elif edad <=18:
  print ("Eres un adolescente")
elif edad <=30:
  print ("Eres un joven adulto")
elif edad <=65:
  print ("Eres un adulto")
else:
    print ("Eres un adulto mayor")
# Out:
# Dame tu edad15
# Eres un adolescente

# %%
edad = int (input ("Dame tu edad"))
if edad >= 65:
  print ("Eres un adulto")
elif edad >=30:
  print ("Eres un joven adulto")
elif edad >=18:
  print ("Eres un adolescente")
elif edad >=10:
  print ("Eres un niño")
else:
    print ("Eres un adulto mayor")
# Out:
# Dame tu edad41
# Eres un joven adulto

# %%
edad = int (input ("Dame tu edad"))
if edad >= 66:
  print ("Eres un adulto mayor")
elif edad >=31 and edad <=65:
  print ("Eres un adulto")
elif edad >=19 and edad <=39:
  print ("Eres un joven adulto")
elif edad >=11 and edad <= 18:
  print ("Eres un adolescente")
else:
    print ("Eres un niño")
# Out:
# Dame tu edad41
# Eres un adulto

# %%
5 > 10 # esto es un comentario, el resultado es valor booleano
       # que me regresa verdadero o falso dependiendo si se cumple o no se cumple la condición
# Out:
# False

# %%
10 > 5
# Out:
# True

# %%
10 > 5 and  10 > 7
# Out:
# True

# %%
10 > 5 and  10 > 7 and 10 > 1 # todas las condiciones son verdaderas
# Out:
# True

# %%
10 > 5 and  10 > 7 and 10 > 11 # es false porque la última condición no la cumple
# Out:
# False

# %%
10 > 5 or  10 > 7 or 10 > 11 # cuando es or basta que uno sea verdadero o falso para el resultado
                             # en este caso es true porque las dos condiciones lo cumplen a pesar de que la última no la cumple
# Out:
# True

# %%
##  Instruction for sirve para repetir instrucciones
tabla = 7
for contador in range(10):  # contador / i significa que tomará valores del 0 al 10 menos el 10 porque es el numero máximo por ende va hasta el 9, no 10
  print (tabla, "*", contador, "=", tabla * contador) # la i / contador puede cambiar y no afecta, puedo poner una c y no afecta
# Out:
# 7 * 0 = 0
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63

# %%
tabla = 7
for i in range(10, 100, 5):  # rango variable inicial 10, general variable fin 100, y va de 5 en 5 incremento
  print (tabla, "*", i, "=", tabla * i)
# Out:
# 7 * 10 = 70
# 7 * 15 = 105
# 7 * 20 = 140
# 7 * 25 = 175
# 7 * 30 = 210
# 7 * 35 = 245
# 7 * 40 = 280
# 7 * 45 = 315
# 7 * 50 = 350
# 7 * 55 = 385
# 7 * 60 = 420
# 7 * 65 = 455
# 7 * 70 = 490
# 7 * 75 = 525
# 7 * 80 = 560
# 7 * 85 = 595
# 7 * 90 = 630
# 7 * 95 = 665

# %%
tabla = int (input ("¿Qué tabla quieres?"))
inicial = int (input ("¿Desde dónde quieres que empiece?"))
fin = int (input ("¿Hasta dónde quieres que termine?"))
incremento = int (input ("¿De cuanto en cuanto quieres que vaya?"))

for i in range (inicial, fin, incremento):
  print(tabla, "*", i, "=", tabla * i)
# Out:
# ¿Qué tabla quieres?5
# ¿Desde dónde quieres que empiece?1
# ¿Hasta dónde quieres que termine?100
# ¿De cuanto en cuanto quieres que vaya?9
# 5 * 1 = 5
# 5 * 10 = 50
# 5 * 19 = 95
# 5 * 28 = 140
# 5 * 37 = 185
# 5 * 46 = 230
# 5 * 55 = 275
# 5 * 64 = 320
# 5 * 73 = 365
# 5 * 82 = 410
# 5 * 91 = 455

# %%
edad = int (input ("Dame tu edad"))   # cambiamos el ELIF por solamente el IF
if edad <= 65:
  print ("Eres un adulto")                    # ponemos if cuando cada uno es independiente en todas y ponemos elif cuando son dependientes de la otra
if edad <=30:i
  print ("Eres un adulto joven")            # aquí con el puro if todas las condiciones se cumple por eso al dar 6 te da todo y el resultado no es el deseado
if edad <=18:
  print ("Eres un adolescente")
if edad <=10:
  print ("Eres un niño")
else:
   print ("Eres un adulto mayor")
# Out:
# Dame tu edad6
# Eres un adulto
# Eres un adulto joven
# Eres un adolescente
# Eres un niño

# %%
numero = 1
while numero <= 6:
  print(numero)
  print ("Dentro del while")
  numero = numero + 1
print ("Fuera del while")
# Out:
# 1
# Dentro del while
# 2
# Dentro del while
# 3
# Dentro del while
# 4
# Dentro del while
# 5
# Dentro del while
# 6
# Dentro del while
# Fuera del while

# %%
# agregamos la intruscción WHILE para que por si los datos están mal formulados,
# te dé la opcion de corregirlo hasta que esté bien formulado y lo valide

tabla = int (input ("¿Qué tabla quieres?"))
inicio = int (input ("¿Desde dónde quieres que empiece?"))
fin = int (input ("¿Hasta dónde quieres que termine?"))
incremento = int (input ("¿De cuanto en cuanto quieres que vaya?"))
while inicio >= fin:
  print ("El límite final debe ser mayor que el inicial")
  final = int (input ("Dame el límite final"))

for i in range (inicio1, fin, incremento):
  print(tabla, "*", i, "=", tabla * i)
# Out:
# ¿Qué tabla quieres?5
# ¿Desde dónde quieres que empiece?10
# ¿Hasta dónde quieres que termine?100
# ¿De cuanto en cuanto quieres que vaya?5
# 5 * 10 = 50
# 5 * 15 = 75
# 5 * 20 = 100
# 5 * 25 = 125
# 5 * 30 = 150
# 5 * 35 = 175
# 5 * 40 = 200
# 5 * 45 = 225
# 5 * 50 = 250
# 5 * 55 = 275
# 5 * 60 = 300
# 5 * 65 = 325
# 5 * 70 = 350
# 5 * 75 = 375
# 5 * 80 = 400
# 5 * 85 = 425
# 5 * 90 = 450
# 5 * 95 = 475

# %% [markdown]
# # **LISTAS DE PYTHON**

# %%
alumnos = ["Ana", "Luis", "Carlos"]
print (alumnos)
# Out:
# ['Ana', 'Luis', 'Carlos']

# %%
alumnos = ["Ana", "manolo", "Carlos"]

print(alumnos)
print(alumnos[0])
print(alumnos[2])
# Out:
# ['Ana', 'manolo', 'Carlos']
# Ana
# Carlos

# %%
#podemos modificar el nuero de la lista insertando nombre y cambiando el numero y posición por el nuevo valor
print(alumnos)
alumnos[2] = "ana"
# Out:
# ['Ana', 'manolo', 'ana']
# ['Ana', 'manolo', 'ana']

# %%
print(alumnos)
print(alumnos[-1])
print(alumnos[-2])
# Out:
# ['Ana', 'manolo', 'ana']
# ana
# manolo

# %%
print(alumnos)

alumnos.append("Sandra")

print(alumnos)
# Out:
# ['Ana', 'manolo', 'ana']
# ['Ana', 'manolo', 'ana', 'Sandra']

# %%
print(alumnos)

alumnos.insert(2, "sofia")

print(alumnos)
# Out:
# ['Ana', 'manolo', 'ana', 'Sandra']
# ['Ana', 'manolo', 'sofia', 'ana', 'Sandra']

# %%
# remove mueve un elemento de la lista con el primer valor que encuentra

print(alumnos)

alumnos.remove("manolo")

print(alumnos)
# Out:
# ['Ana', 'manolo', 'sofia', 'ana', 'Sandra']
# ['Ana', 'sofia', 'ana', 'Sandra']

# %%
# marca error porque queremos añadir un índice que no existe

print(alumnos[2])
print(alumnos[7])
# Out:
# ana
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1847/3203647980.py in <cell line: 0>()
#       2
#       3 print(alumnos[2])
# ----> 4 print(alumnos[7])
#
# IndexError: list index out of range

# %%
# permite eliminar un elemento de la lista especificando su posición

print(alumnos)

alumnos.pop(1)

print(alumnos)
# Out:
# ['Ana', 'sofia', 'ana', 'Sandra']
# ['Ana', 'ana', 'Sandra']

# %%
print("numero de elementos de la lista", len(alumnos))

# len permite conocer el numero de elementos de la lista
# Out:
# numero de elementos de la lista 3

# %%
print(alumnos)

for x in alumnos:
    print(x)

    if x == "manuel":
        print("encontramos a manuel")
        # break fuerza a salir del ciclo
# Out:
# ['Ana', 'ana', 'Sandra']
# Ana
# ana
# Sandra

# %%
print(alumnos)

for x in alumnos:
    print(x)

    if x == "manuel":
        print("encontramos a manuel")
        break #forza a salir del ciclo
# Out:
# ['Ana', 'Luis', 'Carlos']
# Ana
# Luis
# Carlos
