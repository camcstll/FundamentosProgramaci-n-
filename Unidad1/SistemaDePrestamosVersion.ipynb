# %% [markdown]
# <a href="https://colab.research.google.com/github/camcstll/FundamentosProgramaci-n-/blob/main/Unidad1/SistemaDePrestamosVersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INGENIERÍA EN SISTEMAS COMPUTACIONALES**
#
# ## **Fundamentos de Programación**
#
# ## **Unidad 1**
#
# ### Sistema de Gestión de préstamos y reservaciones de computadoras - Versión 1
#
# Docente: **José Gabriel Rodríguez Rivas**
#
# Alumna: **Camila Pérez Castillo**

# %%
# ================================================
# SISTEMA DE PRÉSTAMOS
# Versión 1 - Programación básica y uso de listas
# ================================================

# %%
# Lista de alumnos activos en el sistema
alumnos = [ "26040200", "26040201", "26040202", "26040203", "26040204" ]

# %%
# Cada valor en la lista de computadoras tiene su lista correspondiente con el
# aula donde esta ubicada, el software instalado y el estado de esa computadora
computadoras = [ "PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
                 "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
                 "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04" ]  # PC de compu, LC el aula

# %%
aulas = ["LC1", "LC1", "LC1",
         "LC2", "LC2", "LC2",
         "LC3", "LC3", "LC3", "LC3"] #Las listas ayudan a "almacenar" en lo que tenemos base de datos

# %%
software = ["Python, VS Code", "Python, VS Code", "Python, Java, VS Code",
            "AutoCAD, MATLAB", "Python, VS Code", "Python, Java, VS Code",
            "AutoCAD, MATLAB", "Python, VS Code", "Python, Java, VS Code", "Python, VS Code" ]  #Es el software que tiene cada computadora

# %%
estados = [ "Disponible", "Prestada", "Reservada",
            "Disponible", "Prestada", "Reservada",
            "Disponible", "Prestada", "Reservada", "Mantenimiento" ]  #Significa que x computadora está ocupada o así

# %%
  # MENÚ PRINCIPAL
# Usamos un ciclo While que se repetira indefinidamente hasta que el usuario
# teclee la opcion 7 (salir) o cualquier numero superior a 7
opcion = 0
while opcion <= 6:  #la SANGRIA es lo que está dentro del while
    print("\n================================")
    print("      SISTEMA DE PRÉSTAMOS")
    print("================================")
    print("1. Consultar computadoras")
    print("2. Buscar por software")
    print("3. Solicitar préstamo")
    print("4. Devolver computadora")
    print("5. Crear reservación")
    print("6. Agregar computadora")
    print("7. Salir")
    print("================================")
    opcion = int(input("Seleccione una opción: "))

# %%
opcion = 0
while opcion <=6:
  print ("1. Consultar computadoras", "2. Buscar por software", "3. Solicitar préstamo", "4. Devolver computadora", "5. Crear reservación", "6. Agregar computadora", "7. Salir")
  opcion = int(input("Seleccione una opcion:"))
# Out:
# 1. Consultar computadoras 2. Buscar por software 3. Solicitar préstamo 4. Devolver computadora 5. Crear reservación 6. Agregar computadora 7. Salir

# %%
# 1. Consultar computadoras
    # si el usuario selecciono la opcion 1 se hace un ciclo (for) que recorre
    # toda la lista de computadoras e imprime los valores de las demás listas
    if opcion == 1:  #Esto es si la persona le picó a la opcion 1 del menú
        print("\n--- COMPUTADORAS ---")
        for i in range(len(computadoras)):  #len es para la cantidad de elemntos que tiene la lista y se adapta porque puede que se vayan agregando más o así en vez de poner 7. Si pongo de que 7 y son más solo te pondrá 7, y con el len se adapta si es menos o más o así
            print("Aula:", aulas[i])            # i= 0 / i = 1 / i = 2  -> y así se va incrementando
            print("ID:", computadoras[i])
            print("Software:", software[i])
            print("Estado:", estados[i])
            print("------------------------")

# %%
# 2. Buscar por Software
elif opcion ==2:
  programa = input ("\nIngrese el software que desea buscar: ")
  print("\n--- COMPUTADORAS ---")
  for i in range(len(computadoras)):
    # la función (lower) convierte a minuscula el texto, de esta forma nos aseguramos qu eel texto a buscar y la info de las listas esté en minúscula y no tengamos problema de que no encuentra un programa
    # porque este escrito de forma diferente usando mayusculas y minusculas
    if programa.lower() in software [i].lower():
      print("Aula:", aulas[i])
      print("ID:", computadoras[i])
      print("Software:", software[i])
      print("Estado:", estados[i])
      encontrado = True

  if not encontrado:
    print("No se encontraron computadoras con ese software")
